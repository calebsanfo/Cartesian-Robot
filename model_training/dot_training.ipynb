# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import json
import pandas as pd

from skimage.io import imread, imshow, imread_collection, concatenate_images
import skimage.draw

TRAIN_PATH = 'train/'
TEST_PATH = 'val/'

# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

sys.path.append('../mrcnn')

from config import Config
import utils
import model as modellib
import visualize
from model import log

# %matplotlib inline 

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %%
class MarkConfig(Config):
    """Configuration for training on the cell dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "dot"

    GPU_COUNT = 2
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + cell

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 150
    
    # set validation steps 
    VALIDATION_STEPS = 50
    
    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.5

config = MarkConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.5
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      2
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           dot
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                150
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
class MarkDataset(utils.Dataset):

    def load_shapes(self, subset):
        # Add classes. We have only one class to add.
        self.add_class("dot", 1, "dot")

        # Train or validation dataset?
        dataset_dir = "data/"
        
        if subset == 'train':
            annotations = json.load(open('train.json', 'r'))
        else:
            annotations = json.load(open('val.json', 'r'))
        
        # Add images annotated with Labelbox 
        for a in annotations:
            polygons = []
            class_ids = []
            
            # Get Image Size 
            image_path = os.path.join(dataset_dir, a['External ID'])
            image = imread(image_path)
            height, width = image.shape[:2]
            
#             print (a['Label'].keys)
            
            if 'dot' in a['Label']:
                polys = [r['geometry'] for r in a['Label']['dot']] 

                for i, p in enumerate(polys):
                    x_points = [x['x'] for x in p]
                    y_points = [y['y'] for y in p]
                    polygons.append({'all_points_x': x_points, 'all_points_y': y_points})
                    class_ids.append(1)

            self.add_image(
                "dot",
                image_id=a['External ID'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                class_ids=class_ids)
        
    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a balloon dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "dot":
            return super(self.__class__, self).load_mask(image_id)
        

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        class_ids = info['class_ids']
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.array(class_ids, dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if (info["source"] != "dot"):
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
# Training dataset
dataset_train = MarkDataset()
dataset_train.load_shapes("train")
dataset_train.prepare()


# Validation dataset
dataset_val = MarkDataset()
dataset_val.load_shapes("val")
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 20)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last()[1], by_name=True)

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE, 
            epochs=1, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /home/caleb/Desktop/caminterp/logs/dot20190729T1331/mask_rcnn_dot_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/1
# 150/150 [==============================] - 137s 913ms/step - loss: 0.9914 - rpn_class_loss: 0.0839 - rpn_bbox_loss: 0.3495 - mrcnn_class_loss: 0.0578 - mrcnn_bbox_loss: 0.2601 - mrcnn_mask_loss: 0.2401 - val_loss: 0.9203 - val_rpn_class_loss: 0.0241 - val_rpn_bbox_loss: 0.3948 - val_mrcnn_class_loss: 0.0301 - val_mrcnn_bbox_loss: 0.2394 - val_mrcnn_mask_loss: 0.2319

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=40, 
            layers="all")

model_path = "dotmodel_1class.h5"
model.keras_model.save_weights(model_path)
# Out:
# Starting at epoch 1. LR=0.0001
#
# Checkpoint Path: /home/caleb/Desktop/caminterp/logs/dot20190729T1331/mask_rcnn_dot_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 2/40
# 150/150 [==============================] - 178s 1s/step - loss: 0.5593 - rpn_class_loss: 0.0132 - rpn_bbox_loss: 0.2120 - mrcnn_class_loss: 0.0285 - mrcnn_bbox_loss: 0.1347 - mrcnn_mask_loss: 0.1708 - val_loss: 0.6171 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.2112 - val_mrcnn_class_loss: 0.0348 - val_mrcnn_bbox_loss: 0.1517 - val_mrcnn_mask_loss: 0.2065
# Epoch 3/40
# 150/150 [==============================] - 104s 695ms/step - loss: 0.4054 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.1256 - mrcnn_class_loss: 0.0280 - mrcnn_bbox_loss: 0.0806 - mrcnn_mask_loss: 0.1627 - val_loss: 0.5257 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.1560 - val_mrcnn_class_loss: 0.0298 - val_mrcnn_bbox_loss: 0.1118 - val_mrcnn_mask_loss: 0.2162
# Epoch 4/40
# 150/150 [==============================] - 105s 699ms/step - loss: 0.2898 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.0712 - mrcnn_class_loss: 0.0256 - mrcnn_bbox_loss: 0.0448 - mrcnn_mask_loss: 0.1413 - val_loss: 0.5131 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.1424 - val_mrcnn_class_loss: 0.0301 - val_mrcnn_bbox_loss: 0.1159 - val_mrcnn_mask_loss: 0.2115
# Epoch 5/40
# 150/150 [==============================] - 105s 701ms/step - loss: 0.2503 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.0558 - mrcnn_class_loss: 0.0267 - mrcnn_bbox_loss: 0.0338 - mrcnn_mask_loss: 0.1290 - val_loss: 0.4948 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.1128 - val_mrcnn_class_loss: 0.0411 - val_mrcnn_bbox_loss: 0.1069 - val_mrcnn_mask_loss: 0.2205
# Epoch 6/40
# 150/150 [==============================] - 105s 700ms/step - loss: 0.2307 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.0460 - mrcnn_class_loss: 0.0248 - mrcnn_bbox_loss: 0.0295 - mrcnn_mask_loss: 0.1246 - val_loss: 0.4546 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.1019 - val_mrcnn_class_loss: 0.0312 - val_mrcnn_bbox_loss: 0.1034 - val_mrcnn_mask_loss: 0.2113
# Epoch 7/40
# 150/150 [==============================] - 105s 698ms/step - loss: 0.2070 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.0385 - mrcnn_class_loss: 0.0249 - mrcnn_bbox_loss: 0.0225 - mrcnn_mask_loss: 0.1162 - val_loss: 0.5503 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.1176 - val_mrcnn_class_loss: 0.0332 - val_mrcnn_bbox_loss: 0.1301 - val_mrcnn_mask_loss: 0.2582
# Epoch 8/40
# 150/150 [==============================] - 105s 698ms/step - loss: 0.1843 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0315 - mrcnn_class_loss: 0.0201 - mrcnn_bbox_loss: 0.0170 - mrcnn_mask_loss: 0.1112 - val_loss: 0.4774 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.0962 - val_mrcnn_class_loss: 0.0284 - val_mrcnn_bbox_loss: 0.1138 - val_mrcnn_mask_loss: 0.2296
# Epoch 9/40
# 150/150 [==============================] - 106s 708ms/step - loss: 0.1604 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0227 - mrcnn_class_loss: 0.0194 - mrcnn_bbox_loss: 0.0135 - mrcnn_mask_loss: 0.1003 - val_loss: 0.4963 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.0960 - val_mrcnn_class_loss: 0.0298 - val_mrcnn_bbox_loss: 0.1141 - val_mrcnn_mask_loss: 0.2456
# Epoch 10/40
# 150/150 [==============================] - 106s 706ms/step - loss: 0.1599 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.0257 - mrcnn_class_loss: 0.0163 - mrcnn_bbox_loss: 0.0133 - mrcnn_mask_loss: 0.0996 - val_loss: 0.4497 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.0848 - val_mrcnn_class_loss: 0.0189 - val_mrcnn_bbox_loss: 0.0955 - val_mrcnn_mask_loss: 0.2433
# Epoch 11/40
# 150/150 [==============================] - 104s 690ms/step - loss: 0.1408 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0174 - mrcnn_class_loss: 0.0166 - mrcnn_bbox_loss: 0.0109 - mrcnn_mask_loss: 0.0935 - val_loss: 0.5613 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.1043 - val_mrcnn_class_loss: 0.0373 - val_mrcnn_bbox_loss: 0.1332 - val_mrcnn_mask_loss: 0.2786
# Epoch 12/40
# 150/150 [==============================] - 105s 702ms/step - loss: 0.1438 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0181 - mrcnn_class_loss: 0.0179 - mrcnn_bbox_loss: 0.0098 - mrcnn_mask_loss: 0.0949 - val_loss: 0.4903 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.0882 - val_mrcnn_class_loss: 0.0267 - val_mrcnn_bbox_loss: 0.1161 - val_mrcnn_mask_loss: 0.2549
# Epoch 13/40
# 150/150 [==============================] - 105s 701ms/step - loss: 0.1492 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0212 - mrcnn_class_loss: 0.0145 - mrcnn_bbox_loss: 0.0113 - mrcnn_mask_loss: 0.0986 - val_loss: 0.5030 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.0844 - val_mrcnn_class_loss: 0.0237 - val_mrcnn_bbox_loss: 0.1151 - val_mrcnn_mask_loss: 0.2727
# Epoch 14/40
# 150/150 [==============================] - 105s 702ms/step - loss: 0.1211 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0129 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0849 - val_loss: 0.5493 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.1034 - val_mrcnn_class_loss: 0.0338 - val_mrcnn_bbox_loss: 0.1261 - val_mrcnn_mask_loss: 0.2752
# Epoch 15/40
# 150/150 [==============================] - 105s 703ms/step - loss: 0.1278 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0142 - mrcnn_class_loss: 0.0134 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0901 - val_loss: 0.5410 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.0974 - val_mrcnn_class_loss: 0.0265 - val_mrcnn_bbox_loss: 0.1240 - val_mrcnn_mask_loss: 0.2884
# Epoch 16/40
# 150/150 [==============================] - 106s 704ms/step - loss: 0.1360 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.0162 - mrcnn_class_loss: 0.0153 - mrcnn_bbox_loss: 0.0090 - mrcnn_mask_loss: 0.0905 - val_loss: 0.4886 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.0810 - val_mrcnn_class_loss: 0.0223 - val_mrcnn_bbox_loss: 0.1080 - val_mrcnn_mask_loss: 0.2673
# Epoch 17/40
# 150/150 [==============================] - 104s 695ms/step - loss: 0.1192 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0114 - mrcnn_class_loss: 0.0135 - mrcnn_bbox_loss: 0.0068 - mrcnn_mask_loss: 0.0851 - val_loss: 0.5614 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.0933 - val_mrcnn_class_loss: 0.0306 - val_mrcnn_bbox_loss: 0.1303 - val_mrcnn_mask_loss: 0.2963
# Epoch 18/40
# 150/150 [==============================] - 103s 690ms/step - loss: 0.1213 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0131 - mrcnn_class_loss: 0.0127 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0845 - val_loss: 0.6024 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.0953 - val_mrcnn_class_loss: 0.0379 - val_mrcnn_bbox_loss: 0.1364 - val_mrcnn_mask_loss: 0.3214
# Epoch 19/40
# 150/150 [==============================] - 105s 699ms/step - loss: 0.1203 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0116 - mrcnn_class_loss: 0.0132 - mrcnn_bbox_loss: 0.0072 - mrcnn_mask_loss: 0.0853 - val_loss: 0.4730 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.0734 - val_mrcnn_class_loss: 0.0262 - val_mrcnn_bbox_loss: 0.0969 - val_mrcnn_mask_loss: 0.2718
# Epoch 20/40
# 150/150 [==============================] - 105s 702ms/step - loss: 0.1075 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0096 - mrcnn_class_loss: 0.0114 - mrcnn_bbox_loss: 0.0054 - mrcnn_mask_loss: 0.0789 - val_loss: 0.5058 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.0726 - val_mrcnn_class_loss: 0.0158 - val_mrcnn_bbox_loss: 0.1074 - val_mrcnn_mask_loss: 0.2981
# Epoch 21/40
# 150/150 [==============================] - 104s 694ms/step - loss: 0.1250 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0123 - mrcnn_class_loss: 0.0151 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0872 - val_loss: 0.6342 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.0953 - val_mrcnn_class_loss: 0.0428 - val_mrcnn_bbox_loss: 0.1396 - val_mrcnn_mask_loss: 0.3510
# Epoch 22/40
# 150/150 [==============================] - 104s 694ms/step - loss: 0.0941 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0063 - mrcnn_class_loss: 0.0092 - mrcnn_bbox_loss: 0.0043 - mrcnn_mask_loss: 0.0731 - val_loss: 0.5267 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.0824 - val_mrcnn_class_loss: 0.0244 - val_mrcnn_bbox_loss: 0.1125 - val_mrcnn_mask_loss: 0.2964
# Epoch 23/40
# 150/150 [==============================] - 105s 703ms/step - loss: 0.1186 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0113 - mrcnn_class_loss: 0.0148 - mrcnn_bbox_loss: 0.0068 - mrcnn_mask_loss: 0.0831 - val_loss: 0.5694 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.0826 - val_mrcnn_class_loss: 0.0259 - val_mrcnn_bbox_loss: 0.1231 - val_mrcnn_mask_loss: 0.3273
# Epoch 24/40
# 150/150 [==============================] - 105s 699ms/step - loss: 0.1032 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0087 - mrcnn_class_loss: 0.0109 - mrcnn_bbox_loss: 0.0054 - mrcnn_mask_loss: 0.0758 - val_loss: 0.5393 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.0782 - val_mrcnn_class_loss: 0.0234 - val_mrcnn_bbox_loss: 0.1111 - val_mrcnn_mask_loss: 0.3209
# Epoch 25/40
# 150/150 [==============================] - 104s 695ms/step - loss: 0.1118 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0100 - mrcnn_class_loss: 0.0134 - mrcnn_bbox_loss: 0.0060 - mrcnn_mask_loss: 0.0806 - val_loss: 0.6449 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.0971 - val_mrcnn_class_loss: 0.0351 - val_mrcnn_bbox_loss: 0.1427 - val_mrcnn_mask_loss: 0.3604
# Epoch 26/40
# 150/150 [==============================] - 104s 690ms/step - loss: 0.1003 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0079 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0051 - mrcnn_mask_loss: 0.0749 - val_loss: 0.5705 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.0823 - val_mrcnn_class_loss: 0.0275 - val_mrcnn_bbox_loss: 0.1177 - val_mrcnn_mask_loss: 0.3358
# Epoch 27/40
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0966 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0076 - mrcnn_class_loss: 0.0087 - mrcnn_bbox_loss: 0.0054 - mrcnn_mask_loss: 0.0725 - val_loss: 0.5607 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.0823 - val_mrcnn_class_loss: 0.0326 - val_mrcnn_bbox_loss: 0.1127 - val_mrcnn_mask_loss: 0.3229
# Epoch 28/40
# 150/150 [==============================] - 104s 694ms/step - loss: 0.1118 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0092 - mrcnn_class_loss: 0.0138 - mrcnn_bbox_loss: 0.0056 - mrcnn_mask_loss: 0.0800 - val_loss: 0.6025 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.0854 - val_mrcnn_class_loss: 0.0324 - val_mrcnn_bbox_loss: 0.1363 - val_mrcnn_mask_loss: 0.3413
# Epoch 29/40
# 150/150 [==============================] - 105s 701ms/step - loss: 0.1020 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0085 - mrcnn_class_loss: 0.0103 - mrcnn_bbox_loss: 0.0053 - mrcnn_mask_loss: 0.0756 - val_loss: 0.6113 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.0866 - val_mrcnn_class_loss: 0.0242 - val_mrcnn_bbox_loss: 0.1334 - val_mrcnn_mask_loss: 0.3609
# Epoch 30/40
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0988 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0074 - mrcnn_class_loss: 0.0099 - mrcnn_bbox_loss: 0.0046 - mrcnn_mask_loss: 0.0751 - val_loss: 0.5169 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.0728 - val_mrcnn_class_loss: 0.0248 - val_mrcnn_bbox_loss: 0.1047 - val_mrcnn_mask_loss: 0.3070
# Epoch 31/40
# 150/150 [==============================] - 104s 691ms/step - loss: 0.0939 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0061 - mrcnn_class_loss: 0.0091 - mrcnn_bbox_loss: 0.0045 - mrcnn_mask_loss: 0.0723 - val_loss: 0.6140 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.0850 - val_mrcnn_class_loss: 0.0353 - val_mrcnn_bbox_loss: 0.1304 - val_mrcnn_mask_loss: 0.3534
# Epoch 32/40
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0921 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0062 - mrcnn_class_loss: 0.0097 - mrcnn_bbox_loss: 0.0041 - mrcnn_mask_loss: 0.0698 - val_loss: 0.6921 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.0936 - val_mrcnn_class_loss: 0.0467 - val_mrcnn_bbox_loss: 0.1445 - val_mrcnn_mask_loss: 0.3972
# Epoch 33/40
# 150/150 [==============================] - 103s 689ms/step - loss: 0.1054 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0082 - mrcnn_class_loss: 0.0113 - mrcnn_bbox_loss: 0.0055 - mrcnn_mask_loss: 0.0775 - val_loss: 0.5924 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.0763 - val_mrcnn_class_loss: 0.0330 - val_mrcnn_bbox_loss: 0.1250 - val_mrcnn_mask_loss: 0.3534
# Epoch 34/40
# 150/150 [==============================] - 105s 697ms/step - loss: 0.0881 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0053 - mrcnn_class_loss: 0.0085 - mrcnn_bbox_loss: 0.0037 - mrcnn_mask_loss: 0.0671 - val_loss: 0.5886 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.0813 - val_mrcnn_class_loss: 0.0386 - val_mrcnn_bbox_loss: 0.1209 - val_mrcnn_mask_loss: 0.3403
# Epoch 35/40
# 150/150 [==============================] - 105s 698ms/step - loss: 0.0970 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0068 - mrcnn_class_loss: 0.0094 - mrcnn_bbox_loss: 0.0050 - mrcnn_mask_loss: 0.0742 - val_loss: 0.6433 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.0820 - val_mrcnn_class_loss: 0.0286 - val_mrcnn_bbox_loss: 0.1267 - val_mrcnn_mask_loss: 0.3962
# Epoch 36/40
# 150/150 [==============================] - 104s 696ms/step - loss: 0.1007 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0067 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0749 - val_loss: 0.5583 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.0770 - val_mrcnn_class_loss: 0.0381 - val_mrcnn_bbox_loss: 0.1108 - val_mrcnn_mask_loss: 0.3231
# Epoch 37/40
# 150/150 [==============================] - 104s 691ms/step - loss: 0.0920 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0060 - mrcnn_class_loss: 0.0103 - mrcnn_bbox_loss: 0.0048 - mrcnn_mask_loss: 0.0690 - val_loss: 0.5822 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.0800 - val_mrcnn_class_loss: 0.0315 - val_mrcnn_bbox_loss: 0.1207 - val_mrcnn_mask_loss: 0.3447
# Epoch 38/40
# 150/150 [==============================] - 105s 698ms/step - loss: 0.0881 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0058 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0042 - mrcnn_mask_loss: 0.0697 - val_loss: 0.6298 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.0819 - val_mrcnn_class_loss: 0.0419 - val_mrcnn_bbox_loss: 0.1290 - val_mrcnn_mask_loss: 0.3652
# Epoch 39/40
# 150/150 [==============================] - 105s 697ms/step - loss: 0.0945 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0064 - mrcnn_class_loss: 0.0104 - mrcnn_bbox_loss: 0.0045 - mrcnn_mask_loss: 0.0711 - val_loss: 0.5565 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.0741 - val_mrcnn_class_loss: 0.0288 - val_mrcnn_bbox_loss: 0.1096 - val_mrcnn_mask_loss: 0.3384
# Epoch 40/40
# 150/150 [==============================] - 105s 698ms/step - loss: 0.0875 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0059 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0044 - mrcnn_mask_loss: 0.0678 - val_loss: 0.5730 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.0731 - val_mrcnn_class_loss: 0.0234 - val_mrcnn_bbox_loss: 0.1142 - val_mrcnn_mask_loss: 0.3526
# Epoch 2/40

# %%
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=80, 
            layers="all")

model_path = "dotmodel_1class80.h5"
model.keras_model.save_weights(model_path)
# Out:
# Starting at epoch 40. LR=0.0001
#
# Checkpoint Path: /home/caleb/Desktop/caminterp/logs/dot20190729T1331/mask_rcnn_dot_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 41/80
# 150/150 [==============================] - 179s 1s/step - loss: 0.0954 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0073 - mrcnn_class_loss: 0.0096 - mrcnn_bbox_loss: 0.0054 - mrcnn_mask_loss: 0.0711 - val_loss: 0.6132 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.0815 - val_mrcnn_class_loss: 0.0397 - val_mrcnn_bbox_loss: 0.1221 - val_mrcnn_mask_loss: 0.3618
# Epoch 42/80
# 150/150 [==============================] - 104s 694ms/step - loss: 0.0988 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0073 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0054 - mrcnn_mask_loss: 0.0731 - val_loss: 0.6041 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.0802 - val_mrcnn_class_loss: 0.0300 - val_mrcnn_bbox_loss: 0.1181 - val_mrcnn_mask_loss: 0.3676
# Epoch 43/80
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0887 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0060 - mrcnn_class_loss: 0.0086 - mrcnn_bbox_loss: 0.0042 - mrcnn_mask_loss: 0.0679 - val_loss: 0.5863 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.0765 - val_mrcnn_class_loss: 0.0318 - val_mrcnn_bbox_loss: 0.1168 - val_mrcnn_mask_loss: 0.3522
# Epoch 44/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0904 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0063 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0045 - mrcnn_mask_loss: 0.0689 - val_loss: 0.6601 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.0826 - val_mrcnn_class_loss: 0.0325 - val_mrcnn_bbox_loss: 0.1324 - val_mrcnn_mask_loss: 0.4011
# Epoch 45/80
# 150/150 [==============================] - 104s 694ms/step - loss: 0.0914 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0060 - mrcnn_class_loss: 0.0092 - mrcnn_bbox_loss: 0.0039 - mrcnn_mask_loss: 0.0692 - val_loss: 0.5470 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.0719 - val_mrcnn_class_loss: 0.0277 - val_mrcnn_bbox_loss: 0.1031 - val_mrcnn_mask_loss: 0.3394
# Epoch 46/80
# 150/150 [==============================] - 104s 692ms/step - loss: 0.0919 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0058 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0038 - mrcnn_mask_loss: 0.0700 - val_loss: 0.7057 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.0887 - val_mrcnn_class_loss: 0.0341 - val_mrcnn_bbox_loss: 0.1378 - val_mrcnn_mask_loss: 0.4335
# Epoch 47/80
# 150/150 [==============================] - 103s 688ms/step - loss: 0.1074 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0088 - mrcnn_class_loss: 0.0088 - mrcnn_bbox_loss: 0.0100 - mrcnn_mask_loss: 0.0770 - val_loss: 0.5377 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.0682 - val_mrcnn_class_loss: 0.0299 - val_mrcnn_bbox_loss: 0.1010 - val_mrcnn_mask_loss: 0.3300
# Epoch 48/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0888 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0048 - mrcnn_class_loss: 0.0090 - mrcnn_bbox_loss: 0.0046 - mrcnn_mask_loss: 0.0672 - val_loss: 0.5877 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.0792 - val_mrcnn_class_loss: 0.0309 - val_mrcnn_bbox_loss: 0.1172 - val_mrcnn_mask_loss: 0.3487
# Epoch 49/80
# 150/150 [==============================] - 104s 692ms/step - loss: 0.0867 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0052 - mrcnn_class_loss: 0.0083 - mrcnn_bbox_loss: 0.0032 - mrcnn_mask_loss: 0.0665 - val_loss: 0.5092 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.0680 - val_mrcnn_class_loss: 0.0208 - val_mrcnn_bbox_loss: 0.0909 - val_mrcnn_mask_loss: 0.3227
# Epoch 50/80
# 150/150 [==============================] - 103s 685ms/step - loss: 0.0829 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0035 - mrcnn_mask_loss: 0.0660 - val_loss: 0.6634 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.0886 - val_mrcnn_class_loss: 0.0338 - val_mrcnn_bbox_loss: 0.1327 - val_mrcnn_mask_loss: 0.3999
# Epoch 51/80
# 150/150 [==============================] - 103s 690ms/step - loss: 0.0907 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0056 - mrcnn_class_loss: 0.0086 - mrcnn_bbox_loss: 0.0045 - mrcnn_mask_loss: 0.0697 - val_loss: 0.5860 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.0774 - val_mrcnn_class_loss: 0.0331 - val_mrcnn_bbox_loss: 0.1126 - val_mrcnn_mask_loss: 0.3581
# Epoch 52/80
# 150/150 [==============================] - 104s 691ms/step - loss: 0.0925 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0061 - mrcnn_class_loss: 0.0085 - mrcnn_bbox_loss: 0.0043 - mrcnn_mask_loss: 0.0710 - val_loss: 0.5766 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.0742 - val_mrcnn_class_loss: 0.0277 - val_mrcnn_bbox_loss: 0.1132 - val_mrcnn_mask_loss: 0.3549
# Epoch 53/80
# 150/150 [==============================] - 105s 700ms/step - loss: 0.0772 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0038 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0032 - mrcnn_mask_loss: 0.0610 - val_loss: 0.6383 - val_rpn_class_loss: 0.0133 - val_rpn_bbox_loss: 0.0872 - val_mrcnn_class_loss: 0.0398 - val_mrcnn_bbox_loss: 0.1248 - val_mrcnn_mask_loss: 0.3733
# Epoch 54/80
# 150/150 [==============================] - 104s 694ms/step - loss: 0.0822 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0043 - mrcnn_class_loss: 0.0077 - mrcnn_bbox_loss: 0.0030 - mrcnn_mask_loss: 0.0656 - val_loss: 0.6330 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.0813 - val_mrcnn_class_loss: 0.0382 - val_mrcnn_bbox_loss: 0.1162 - val_mrcnn_mask_loss: 0.3922
# Epoch 55/80
# 150/150 [==============================] - 105s 703ms/step - loss: 0.0873 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0048 - mrcnn_class_loss: 0.0089 - mrcnn_bbox_loss: 0.0031 - mrcnn_mask_loss: 0.0666 - val_loss: 0.5880 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.0716 - val_mrcnn_class_loss: 0.0354 - val_mrcnn_bbox_loss: 0.1141 - val_mrcnn_mask_loss: 0.3571
# Epoch 56/80
# 150/150 [==============================] - 104s 691ms/step - loss: 0.0809 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0030 - mrcnn_mask_loss: 0.0640 - val_loss: 0.5727 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.0714 - val_mrcnn_class_loss: 0.0289 - val_mrcnn_bbox_loss: 0.1051 - val_mrcnn_mask_loss: 0.3571
# Epoch 57/80
# 150/150 [==============================] - 104s 693ms/step - loss: 0.0795 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0042 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0632 - val_loss: 0.6664 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.0875 - val_mrcnn_class_loss: 0.0388 - val_mrcnn_bbox_loss: 0.1263 - val_mrcnn_mask_loss: 0.4054
# Epoch 58/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0808 - rpn_class_loss: 0.0021 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0077 - mrcnn_bbox_loss: 0.0030 - mrcnn_mask_loss: 0.0638 - val_loss: 0.6240 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.0791 - val_mrcnn_class_loss: 0.0380 - val_mrcnn_bbox_loss: 0.1211 - val_mrcnn_mask_loss: 0.3786
# Epoch 59/80
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0777 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0039 - mrcnn_class_loss: 0.0076 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0615 - val_loss: 0.5455 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.0633 - val_mrcnn_class_loss: 0.0193 - val_mrcnn_bbox_loss: 0.0960 - val_mrcnn_mask_loss: 0.3551
# Epoch 60/80
# 150/150 [==============================] - 103s 687ms/step - loss: 0.0885 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0051 - mrcnn_class_loss: 0.0090 - mrcnn_bbox_loss: 0.0042 - mrcnn_mask_loss: 0.0687 - val_loss: 0.6762 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.0841 - val_mrcnn_class_loss: 0.0514 - val_mrcnn_bbox_loss: 0.1276 - val_mrcnn_mask_loss: 0.4076
# Epoch 61/80
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0727 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0032 - mrcnn_class_loss: 0.0052 - mrcnn_bbox_loss: 0.0033 - mrcnn_mask_loss: 0.0598 - val_loss: 0.5897 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.0777 - val_mrcnn_class_loss: 0.0299 - val_mrcnn_bbox_loss: 0.1102 - val_mrcnn_mask_loss: 0.3609
# Epoch 62/80
# 150/150 [==============================] - 106s 707ms/step - loss: 0.0891 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0054 - mrcnn_class_loss: 0.0079 - mrcnn_bbox_loss: 0.0047 - mrcnn_mask_loss: 0.0691 - val_loss: 0.6453 - val_rpn_class_loss: 0.0122 - val_rpn_bbox_loss: 0.0791 - val_mrcnn_class_loss: 0.0301 - val_mrcnn_bbox_loss: 0.1221 - val_mrcnn_mask_loss: 0.4019
# Epoch 63/80
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0796 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0041 - mrcnn_class_loss: 0.0067 - mrcnn_bbox_loss: 0.0034 - mrcnn_mask_loss: 0.0634 - val_loss: 0.5472 - val_rpn_class_loss: 0.0070 - val_rpn_bbox_loss: 0.0669 - val_mrcnn_class_loss: 0.0278 - val_mrcnn_bbox_loss: 0.1006 - val_mrcnn_mask_loss: 0.3450
# Epoch 64/80
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0885 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0048 - mrcnn_class_loss: 0.0095 - mrcnn_bbox_loss: 0.0046 - mrcnn_mask_loss: 0.0682 - val_loss: 0.6567 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.0906 - val_mrcnn_class_loss: 0.0354 - val_mrcnn_bbox_loss: 0.1364 - val_mrcnn_mask_loss: 0.3857
# Epoch 65/80
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0777 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0036 - mrcnn_class_loss: 0.0067 - mrcnn_bbox_loss: 0.0034 - mrcnn_mask_loss: 0.0620 - val_loss: 0.6325 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.0774 - val_mrcnn_class_loss: 0.0283 - val_mrcnn_bbox_loss: 0.1153 - val_mrcnn_mask_loss: 0.4030
# Epoch 66/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0774 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0039 - mrcnn_class_loss: 0.0067 - mrcnn_bbox_loss: 0.0037 - mrcnn_mask_loss: 0.0612 - val_loss: 0.5600 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.0735 - val_mrcnn_class_loss: 0.0319 - val_mrcnn_bbox_loss: 0.1056 - val_mrcnn_mask_loss: 0.3403
# Epoch 67/80
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0895 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0050 - mrcnn_class_loss: 0.0092 - mrcnn_bbox_loss: 0.0040 - mrcnn_mask_loss: 0.0689 - val_loss: 0.5886 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.0758 - val_mrcnn_class_loss: 0.0338 - val_mrcnn_bbox_loss: 0.1156 - val_mrcnn_mask_loss: 0.3565
# Epoch 68/80
# 150/150 [==============================] - 105s 698ms/step - loss: 0.0778 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0038 - mrcnn_class_loss: 0.0071 - mrcnn_bbox_loss: 0.0028 - mrcnn_mask_loss: 0.0621 - val_loss: 0.6458 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.0809 - val_mrcnn_class_loss: 0.0318 - val_mrcnn_bbox_loss: 0.1178 - val_mrcnn_mask_loss: 0.4090
# Epoch 69/80
# 150/150 [==============================] - 104s 693ms/step - loss: 0.0764 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0027 - mrcnn_mask_loss: 0.0615 - val_loss: 0.5681 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.0729 - val_mrcnn_class_loss: 0.0286 - val_mrcnn_bbox_loss: 0.1075 - val_mrcnn_mask_loss: 0.3510
# Epoch 70/80
# 150/150 [==============================] - 105s 698ms/step - loss: 0.0730 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0030 - mrcnn_class_loss: 0.0069 - mrcnn_bbox_loss: 0.0026 - mrcnn_mask_loss: 0.0592 - val_loss: 0.6019 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.0750 - val_mrcnn_class_loss: 0.0357 - val_mrcnn_bbox_loss: 0.1136 - val_mrcnn_mask_loss: 0.3674
# Epoch 71/80
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0730 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0075 - mrcnn_bbox_loss: 0.0026 - mrcnn_mask_loss: 0.0580 - val_loss: 0.6498 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.0839 - val_mrcnn_class_loss: 0.0428 - val_mrcnn_bbox_loss: 0.1244 - val_mrcnn_mask_loss: 0.3896
# Epoch 72/80
# 150/150 [==============================] - 104s 695ms/step - loss: 0.0811 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0042 - mrcnn_class_loss: 0.0077 - mrcnn_bbox_loss: 0.0028 - mrcnn_mask_loss: 0.0639 - val_loss: 0.6291 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.0736 - val_mrcnn_class_loss: 0.0359 - val_mrcnn_bbox_loss: 0.1133 - val_mrcnn_mask_loss: 0.4022
# Epoch 73/80
# 150/150 [==============================] - 104s 697ms/step - loss: 0.0725 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0027 - mrcnn_class_loss: 0.0070 - mrcnn_bbox_loss: 0.0022 - mrcnn_mask_loss: 0.0572 - val_loss: 0.5974 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.0760 - val_mrcnn_class_loss: 0.0348 - val_mrcnn_bbox_loss: 0.1140 - val_mrcnn_mask_loss: 0.3658
# Epoch 74/80
# 150/150 [==============================] - 105s 700ms/step - loss: 0.0752 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0034 - mrcnn_class_loss: 0.0072 - mrcnn_bbox_loss: 0.0025 - mrcnn_mask_loss: 0.0608 - val_loss: 0.6066 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.0753 - val_mrcnn_class_loss: 0.0266 - val_mrcnn_bbox_loss: 0.1102 - val_mrcnn_mask_loss: 0.3848
# Epoch 75/80
# 150/150 [==============================] - 104s 693ms/step - loss: 0.0796 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0037 - mrcnn_class_loss: 0.0088 - mrcnn_bbox_loss: 0.0027 - mrcnn_mask_loss: 0.0624 - val_loss: 0.6366 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.0757 - val_mrcnn_class_loss: 0.0343 - val_mrcnn_bbox_loss: 0.1184 - val_mrcnn_mask_loss: 0.3982
# Epoch 76/80
# 150/150 [==============================] - 104s 691ms/step - loss: 0.0727 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0066 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0584 - val_loss: 0.6053 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.0748 - val_mrcnn_class_loss: 0.0330 - val_mrcnn_bbox_loss: 0.1047 - val_mrcnn_mask_loss: 0.3882
# Epoch 77/80
# 150/150 [==============================] - 105s 699ms/step - loss: 0.0745 - rpn_class_loss: 0.0011 - rpn_bbox_loss: 0.0036 - mrcnn_class_loss: 0.0049 - mrcnn_bbox_loss: 0.0037 - mrcnn_mask_loss: 0.0611 - val_loss: 0.6366 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.0740 - val_mrcnn_class_loss: 0.0461 - val_mrcnn_bbox_loss: 0.1302 - val_mrcnn_mask_loss: 0.3738
# Epoch 78/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0755 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0038 - mrcnn_class_loss: 0.0074 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0599 - val_loss: 0.6201 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.0708 - val_mrcnn_class_loss: 0.0366 - val_mrcnn_bbox_loss: 0.1094 - val_mrcnn_mask_loss: 0.3979
# Epoch 79/80
# 150/150 [==============================] - 104s 696ms/step - loss: 0.0726 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0033 - mrcnn_class_loss: 0.0062 - mrcnn_bbox_loss: 0.0029 - mrcnn_mask_loss: 0.0585 - val_loss: 0.6117 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.0681 - val_mrcnn_class_loss: 0.0288 - val_mrcnn_bbox_loss: 0.1100 - val_mrcnn_mask_loss: 0.3943
# Epoch 80/80
# 150/150 [==============================] - 105s 702ms/step - loss: 0.0780 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0036 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0031 - mrcnn_mask_loss: 0.0609 - val_loss: 0.6070 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.0751 - val_mrcnn_class_loss: 0.0268 - val_mrcnn_bbox_loss: 0.1161 - val_mrcnn_mask_loss: 0.3793

# %%
class InferenceConfig(MarkConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
# model_path = model.find_last()[1]

# Load trained weights (fill in path to trained weights here)
model_path = 'dotmodel_1class80.h5'
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  dotmodel_1class80.h5

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:  177.00000  uint8
# image_meta               shape: (16,)                 min:    0.00000  max: 1024.00000  float64
# gt_class_id              shape: (7,)                  min:    3.00000  max:    3.00000  int32
# gt_bbox                  shape: (7, 4)                min:  204.00000  max:  926.00000  int32
# gt_mask                  shape: (1024, 1024, 7)       min:    0.00000  max:    1.00000  bool

# %%
# from matplotlib.image import imread
img = skimage.io.imread('WIN_20190728_12_54_28_Pro.jpg')
print(type(img))
print(img.shape)

results = model.detect([img], verbose=1)

r = results[0]
visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# <class 'imageio.core.util.Array'>
# (1080, 1920, 3)
# Processing 1 images
# image                    shape: (1080, 1920, 3)       min:    0.00000  max:  240.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  134.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1920.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
def get_mark_center(rois):
    centroids = []
    for dot in rois:
        centroids.append(np.stack([
            dot[1] + ((dot[3] - dot[1]) / 2.0),
            dot[0] + ((dot[2] - dot[0]) / 2.0),
        ], -1))
    return centroids

def find_dots(model):
    results = model.detect([original_image], verbose=1)
    r = results[0]
    if len(r['rois']) > 0:
        centroids = get_mark_center(r['rois'])
        return centroids, original_image, r

# %%
centroids, orig_frame, r = find_dots(model)
print(centroids)
print(centroids[0])
print(centroids[1])
print(centroids[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-67eddc286bfa> in <module>
# ----> 1 centroids, orig_frame, r = find_dots(model)
#       2 print(centroids)
#       3 print(centroids[0])
#       4 print(centroids[1])
#       5 print(centroids[2])
#
# <ipython-input-19-981727157c86> in find_dots(model)
#       9
#      10 def find_dots(model):
# ---> 11     results = model.detect([original_image], verbose=1)
#      12     r = results[0]
#      13     if len(r['rois']) > 0:
#
# NameError: name 'original_image' is not defined

# %%
from skimage import draw
import matplotlib.pyplot as plt
def visualize_marker_centers(img, centers, color=0):
    for center in centers:
        res = img.copy()
        rr, cc = draw.circle(center[1], center[0], radius=5, shape=img.shape)
        res[rr, cc] = color
        return res
plt.imshow(visualize_marker_centers(original_image, centroids, [0, 0, 0]))
plt.gcf().set_size_inches(20, 14)
